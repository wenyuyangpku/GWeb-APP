# %%
import pandas as pd
import json

# %%
ss=pd.read_json("Output.json")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-1d3c3e67b739> in <module>()
# ----> 1 ss=pd.read_json("Output.json",split)
#
# NameError: name 'split' is not defined

# %%
ss.to_json("test.json",orient='records')

# %%
aa=json.load(aa)

# %%
c={}

# %%
ss.iloc[1][22]
# Out:
# 'Plays and other writings from the Elizabethan, Jacobean, and Restoration eras and the eighteenth century. The historical world in which the plays were written as well as the imaginary worlds created in the plays themselves.'

# %%
ss.to_csv("output.csv")

# %%
ss
# Out:
#           CRN Subject Course Section Campus       Credit  \
# 0     24986.0     ACA   6201      10      1            3
# 1     24987.0     ACA   6205      10      1            2
# 10    21211.0    ACCY   2001      11      1            3
# 100   22721.0    AMST   2010      83      1            0
# 1000  21107.0    CNSL   8999      15    IR1  3.000/6.000
# 1001  21256.0    CNSL   8999      16    IR1  3.000/6.000
# 1002  21482.0    CNSL   8999      17    IR1  3.000/6.000
# 1003  23106.0    CNSL   8999      18    IR1  3.000/6.000
# 1004  27412.0    CNSL   8999      19    IR1            6
# 1005  27706.0    COHM   6210      DA      7            3
# 1006  21328.0    COMM   1025      10      1            3
# 1007  20769.0    COMM   1040      10      1            3
# 1008  23592.0    COMM   1040      11      1            3
# 1009  20770.0    COMM   1040      12      1            3
# 101   22722.0    AMST   2010      84      1            0
# ...

# %%
fo=open("test.txt","w")

# %%
for i in range(len(ss)):
    for j in range(23):
        fo.write(str(ss.iloc[i][j])+'\n')

# %%
fo.close()

# %%
ss
# Out:
#           CRN Subject Course Section Campus       Credit  \
# 0     24986.0     ACA   6201      10      1            3
# 1     24987.0     ACA   6205      10      1            2
# 10    21211.0    ACCY   2001      11      1            3
# 100   22721.0    AMST   2010      83      1            0
# 1000  21107.0    CNSL   8999      15    IR1  3.000/6.000
# 1001  21256.0    CNSL   8999      16    IR1  3.000/6.000
# 1002  21482.0    CNSL   8999      17    IR1  3.000/6.000
# 1003  23106.0    CNSL   8999      18    IR1  3.000/6.000
# 1004  27412.0    CNSL   8999      19    IR1            6
# 1005  27706.0    COHM   6210      DA      7            3
# 1006  21328.0    COMM   1025      10      1            3
# 1007  20769.0    COMM   1040      10      1            3
# 1008  23592.0    COMM   1040      11      1            3
# 1009  20770.0    COMM   1040      12      1            3
# 101   22722.0    AMST   2010      84      1            0
# ...
